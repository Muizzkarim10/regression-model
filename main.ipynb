# %%
import pandas as pd

# %%
df = pd.read_excel("Horse_List_02_Apr_2025.xlsx")

# %%
df
# Out:
#                    Horse Name         Date         CVS  Distance  \
# 0     ROMANTIC WARRIOR (E486)  28-Apr-2024    GR S / A    2000.0
# 1     ROMANTIC WARRIOR (E486)  17-Nov-2024  GR S / B+2    2000.0
# 2     ROMANTIC WARRIOR (E486)  08-Dec-2024    GR S / A    2000.0
# 3      LUCKY SWEYNESSE (G180)  07-Apr-2024  GR S / B+2    1200.0
# 4       KA YING RISING (J062)  05-May-2024     2 S / B    1200.0
# ...                       ...          ...         ...       ...
# 8320   JOYFUL CHAMPION (G072)  18-Dec-2024    5 S / AW    1800.0
# 8321   JOYFUL CHAMPION (G072)  01-Jan-2025     5 S / C    1800.0
# 8322   JOYFUL CHAMPION (G072)  26-Jan-2025    5 S / AW    1650.0
# 8323   JOYFUL CHAMPION (G072)  05-Mar-2025   5 H / C+3    2200.0
# 8324   JOYFUL CHAMPION (G072)  26-Mar-2025    5 S / AW    1800.0
#
#       Sectional Time  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                7.0         3.0         7.0         4.0         1.0
# ...

# %% [markdown]
# # Missing values
# - **Alot of missing values some cols are totally empty.** <br>
# - below are the number of missing values in respective column.

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Horse Name           0
# Date               257
# CVS                257
# Distance           257
# Sectional Time     257
# Unnamed: 5         257
# Unnamed: 6         258
# Unnamed: 7         258
# Unnamed: 8         261
# Unnamed: 9         261
# P1                 257
# PP                 257
# SR                 257
# TA                 257
# MGT                257
# SM                 257
# FFA                257
# HFFA               257
# R                 1263
# QSP                257
# UPC               4962
# iZ                6173
# WPP               8325
# S                 6833
# PPS               8144
# Dr                8325
# Rtg               8325
# TMP               7182
# BO5               7064
# GR                5207
# *                 8325
# #                 8325
# ?                 8325
# %                 8325
# SW                8028
# NM                8325
# FS                8325
# G                 8325
# Odds              8325
# HW                8325
# ...

# %% [markdown]
# # relation of column I (unnamed 8 in this case) with others
# - **Value closer to 1 means strong positive impact, value close to negative -1 means strong negative on the targeted col.** <br>
# - **NaN means no relation**

# %%
dff = pd.read_csv("gr_and_i.csv")

# %%
# Converting GR to numeric values
dff["GR"] = dff["GR"].replace({"G": 1, "GR": 2, "G1": 3})
correlation = dff[["GR", "i"]].dropna().corr()

filtered_df = dff[dff["GR"] == 1]

# Count how many times 1 appears in the "i" column
count_ones_in_i = (filtered_df["i"] == 1).sum()

print(f"The value 1 appears {count_ones_in_i} times in the 'i' column where 'GR' = 'G'.")
print(correlation)
# Out:
# The value 1 appears 588 times in the 'i' column where 'GR' = 'G'.
#           GR         i
# GR  1.000000  0.433179
# i   0.433179  1.000000
# /tmp/ipykernel_433156/3069801381.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dff["GR"] = dff["GR"].replace({"G": 1, "GR": 2, "G1": 3})
